# %% [markdown]
# # City school analysis

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("D:/Data analytics bootcamp/week4/module_4_challenge/panda-challenge/Starter_Code (1)/Starter_Code/PyCitySchools/Resources/schools_complete.csv")
student_data_to_load = Path("D:/Data analytics bootcamp/week4/module_4_challenge/panda-challenge/Starter_Code (1)/Starter_Code/PyCitySchools/Resources/students_complete.csv")

# read in the dataset:
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

#merging the two datasets
merged_data = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
merged_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# # District Summary

# %%
# Total Number of Unique Schools
total_schools = len(merged_data['School ID'].unique())

# Total Number of Students
total_students = len(merged_data['Student ID'].unique())
total_students_fmt = '{:,}'.format(total_students) # format with comma separators

# Total Budget
total_budget = school_data['budget'].sum()
total_budget_fmt = '${:,.0f}'.format(total_budget) # format with dollar sign symbol

# Average Math Score
avg_math_score = student_data['math_score'].mean()

# Average Reading Score 
avg_reading_score = student_data['reading_score'].mean()

# % Passing Math
passing_math = student_data[student_data['math_score'] >= 70].count()['Student ID']/total_students * 100

# % Passing Reading
passing_reading = student_data[student_data['reading_score'] >= 70].count()['Student ID']/total_students * 100

# Overall Passing Rate
overall_passing = merged_data[(merged_data['math_score'] >= 70) & (merged_data['reading_score'] >= 70)].count()['Student ID']/total_students * 100

# %%
#creating a DataFrame to display the district summary

district_summary = pd.DataFrame({
    "Total Schools": [total_schools],
    "Total Students": [total_students_fmt],
    "Total Budget": [total_budget_fmt],
    "Average Math Score": [avg_math_score],
    "Average Reading Score": [avg_reading_score],
    "% Passing Math": [passing_math],
    "% Passing Reading": [passing_reading],
    "% Overall Passing": [overall_passing]
})

district_summary
# Out:
#    Total Schools Total Students Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# # School summary

# %%
# Calculate the total number of students per school
student_count = merged_data.groupby(['school_name']).size()

# Calculate the total budget per school
budget_per_school = merged_data.groupby(['school_name'])['budget'].mean()

# Calculate the budget per student per school
budget_per_student = budget_per_school / student_count

# Calculate the average math score per school
average_math_score = merged_data.groupby(['school_name'])['math_score'].mean()

# Calculate the average reading score per school
average_reading_score = merged_data.groupby(['school_name'])['reading_score'].mean()

# Calculate the percentage of students who passed math per school
passing_math_count = merged_data[merged_data['math_score'] >= 70].groupby(['school_name']).size()
percent_passing_math = passing_math_count / student_count * 100

# Calculate the percentage of students who passed reading per school
passing_reading_count = merged_data[merged_data['reading_score'] >= 70].groupby(['school_name']).size()
percent_passing_reading = passing_reading_count / student_count * 100

# Calculate the overall passing percentage per school
overall_passing_percent = (percent_passing_math + percent_passing_reading) / 2

# %%
# Combine all the above calculations into a summary DataFrame
summary_df = pd.DataFrame({
    'School Type': school_data.set_index('school_name')['type'],
    'Total Students': student_count,
    'Total School Budget': budget_per_school,
    'Per Student Budget': budget_per_student,
    'Average Math Score': average_math_score,
    'Average Reading Score': average_reading_score,
    '% Passing Math': percent_passing_math,
    '% Passing Reading': percent_passing_reading,
    '% Overall Passing Rate': overall_passing_percent
})

# %%
# Format the columns appropriately
summary_df['Total Students'] = summary_df['Total Students'].map('{:,}'.format)
summary_df['Total School Budget']=summary_df['Total School Budget']. map('${:,.2f}'.format)
summary_df['Per Student Budget']=summary_df['Per Student Budget']. map('${:.2f}'.format)

# Display the summary DataFrame
summary_df
# Out:
#                       School Type Total Students Total School Budget  \
# school_name
# Bailey High School       District          4,976       $3,124,928.00
# Cabrera High School       Charter          1,858       $1,081,356.00
# Figueroa High School     District          2,949       $1,884,411.00
# Ford High School         District          2,739       $1,763,916.00
# Griffin High School       Charter          1,468         $917,500.00
# Hernandez High School    District          4,635       $3,022,020.00
# Holden High School        Charter            427         $248,087.00
# Huang High School        District          2,917       $1,910,635.00
# Johnson High School      District          4,761       $3,094,650.00
# Pena High School          Charter            962         $585,858.00
# Rodriguez High School    District          3,999       $2,547,363.00
# Shelton High School       Charter          1,761       $1,056,600.00
# ...

# %% [markdown]
# # Highest-Performing Schools

# %%
top_schools = summary_df.sort_values(by='% Overall Passing Rate',ascending=False).head(5)

top_schools
# Out:
#                     School Type Total Students Total School Budget  \
# school_name
# Cabrera High School     Charter          1,858       $1,081,356.00
# Thomas High School      Charter          1,635       $1,043,130.00
# Pena High School        Charter            962         $585,858.00
# Griffin High School     Charter          1,468         $917,500.00
# Wilson High School      Charter          2,283       $1,319,574.00
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Pena High School               $609.00           83.839917
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %% [markdown]
# # Lowest-Performing Schools

# %%
bottom_schools = summary_df.sort_values(by='% Overall Passing Rate',ascending=True).head(5)

bottom_schools
# Out:
#                       School Type Total Students Total School Budget  \
# school_name
# Rodriguez High School    District          3,999       $2,547,363.00
# Figueroa High School     District          2,949       $1,884,411.00
# Huang High School        District          2,917       $1,910,635.00
# Johnson High School      District          4,761       $3,094,650.00
# Ford High School         District          2,739       $1,763,916.00
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Johnson High School              $650.00           77.072464
# Ford High School                 $644.00           77.102592
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Rodriguez High School              80.744686       66.366592
# ...

# %% [markdown]
# # Math Scores by Grade

# %%
# Create a pivot table to display the average math score for students of each grade level at each school
math_scores_by_grade = pd.pivot_table(student_data, values = 'math_score', index=['school_name'], columns = ['grade'], aggfunc = 'mean')

# Update the column names to include "Math"
math_scores_by_grade.columns = ['9th Grade Math', '10th Grade Math', '11th Grade Math', '12th Grade Math']

# Remove the index name
math_scores_by_grade.index.name = None

# Display the math scores by grade DataFrame
math_scores_by_grade
# Out:
#                        9th Grade Math  10th Grade Math  11th Grade Math  \
# Bailey High School          76.996772        77.515588        76.492218
# Cabrera High School         83.154506        82.765560        83.277487
# Figueroa High School        76.539974        76.884344        77.151369
# Ford High School            77.672316        76.918058        76.179963
# Griffin High School         84.229064        83.842105        83.356164
# Hernandez High School       77.337408        77.136029        77.186567
# Holden High School          83.429825        85.000000        82.855422
# Huang High School           75.908735        76.446602        77.225641
# Johnson High School         76.691117        77.491653        76.863248
# Pena High School            83.372000        84.328125        84.121547
# Rodriguez High School       76.612500        76.395626        77.690748
# Shelton High School         82.917411        83.383495        83.778976
# ...

# %% [markdown]
# # Reading Scores by Grade

# %%
# Create a pivot table to display the average reading score for students of each grade level at each school
reading_scores_by_grade = pd.pivot_table(student_data, values = 'reading_score', index=['school_name'], columns = ['grade'], aggfunc = 'mean')

# Update the column names to include "Reading"
reading_scores_by_grade.columns = ['9th Grade Reading', '10th Grade Reading', '11th Grade Reading', '12th Grade Reading']

# Remove the index name
reading_scores_by_grade.index.name = None

# Display the reading scores by grade DataFrame
reading_scores_by_grade
# Out:
#                        9th Grade Reading  10th Grade Reading  \
# Bailey High School             80.907183           80.945643
# Cabrera High School            84.253219           83.788382
# Figueroa High School           81.408912           80.640339
# Ford High School               81.262712           80.403642
# Griffin High School            83.706897           84.288089
# Hernandez High School          80.660147           81.396140
# Holden High School             83.324561           83.815534
# Huang High School              81.512386           81.417476
# Johnson High School            80.773431           80.616027
# Pena High School               83.612000           84.335938
# Rodriguez High School          80.629808           80.864811
# Shelton High School            83.441964           84.373786
# Thomas High School             84.254157           83.585542
# Wilson High School             84.021452           83.764608
# ...

# %% [markdown]
# # Scores by School Spending

# %%
# Create four bins with reasonable cutoff values to group school spending
spending_bins = [0, 585, 630, 645, 680]

# Create labels for these bins
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

# Create a copy of the school summary since it has the "Per Student Budget" 
summary_df = summary_df.copy()

#converting dataframe column to float
summary_df['Per Student Budget'] = pd.to_numeric(summary_df['Per Student Budget'].replace('[^0-9.]', '', regex=True), errors='coerce')


# Use pd.cut to categorize spending based on the bins
summary_df['Spending Ranges (Per Student)'] = pd.cut(summary_df['Per Student Budget'], bins=spending_bins, labels=labels)

summary_df
# Out:
#                       School Type Total Students Total School Budget  \
# school_name
# Bailey High School       District          4,976       $3,124,928.00
# Cabrera High School       Charter          1,858       $1,081,356.00
# Figueroa High School     District          2,949       $1,884,411.00
# Ford High School         District          2,739       $1,763,916.00
# Griffin High School       Charter          1,468         $917,500.00
# Hernandez High School    District          4,635       $3,022,020.00
# Holden High School        Charter            427         $248,087.00
# Huang High School        District          2,917       $1,910,635.00
# Johnson High School      District          4,761       $3,094,650.00
# Pena High School          Charter            962         $585,858.00
# Rodriguez High School    District          3,999       $2,547,363.00
# Shelton High School       Charter          1,761       $1,056,600.00
# ...

# %%
# Calculate mean scores per spending range
spending_math_scores = summary_df.groupby(['Spending Ranges (Per Student)'])['Average Math Score'].mean()
spending_reading_scores = summary_df.groupby(['Spending Ranges (Per Student)'])['Average Reading Score'].mean()
spending_passing_math = summary_df.groupby(['Spending Ranges (Per Student)'])['% Passing Math'].mean()
spending_passing_reading = summary_df.groupby(['Spending Ranges (Per Student)'])['% Passing Reading'].mean()
overall_passing_spending = summary_df.groupby(['Spending Ranges (Per Student)'])['% Overall Passing Rate'].mean()

# %%
#Create a DataFrame to summarize scores by school spending
spending_summary = pd.DataFrame({
    'Average Math Score': spending_math_scores,
    'Average Reading Score': spending_reading_scores,
    '% Passing Math': spending_passing_math,
    '% Passing Reading': spending_passing_reading,
    '% Overall Passing Rate': overall_passing_spending
})

# %%
# Format the columns appropriately
spending_summary['Average Math Score'] = spending_summary['Average Math Score'].map('{:.2f}'.format)
spending_summary['Average Reading Score'] = spending_summary['Average Reading Score'].map('{:.2f}'.format)
spending_summary['% Passing Math'] = spending_summary['% Passing Math'].map('{:.2f}'.format)
spending_summary['% Passing Reading'] = spending_summary['% Passing Reading'].map('{:.2f}'.format)
spending_summary['% Overall Passing Rate'] = spending_summary['% Overall Passing Rate'].map('{:.2f}'.format)

# %%
# Display the spending summary DataFrame
spending_summary
# Out:
#                               Average Math Score Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                      83.46                 83.93
# $585-630                                   81.90                 83.16
# $630-645                                   78.52                 81.62
# $645-680                                   77.00                 81.03
#
#                               % Passing Math % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                                  93.46             96.61
# $585-630                               87.13             92.72
# $630-645                               73.48             84.39
# $645-680                               66.16             81.13
#
#                               % Overall Passing Rate
# Spending Ranges (Per Student)
# <$585                                          95.04
# $585-630                                       89.93
# ...

# %% [markdown]
# # Scores by School Size

# %%
# Create bins for school size and labels for the bins
size_bins = [0, 1000, 2000, 5000]
size_labels = ['Small (0-1000)', 'Medium (1000-2000)', 'Large (2000-5000)']

#converting dataframe column to float
summary_df['Total Students'] = pd.to_numeric(summary_df['Total Students'].replace('[^0-9.]', '', regex=True), errors='coerce')

# Use pd.cut on the "Total Students" column to categorize schools based on size
summary_df['School Size'] = pd.cut(summary_df['Total Students'], bins=size_bins, labels=size_labels)

summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %%
# Create a DataFrame to summarize scores by school size
size_summary = pd.DataFrame({
    'Average Math Score': summary_df.groupby(['School Size'])['Average Math Score'].mean(),
    'Average Reading Score': summary_df.groupby(['School Size'])['Average Reading Score'].mean(),
    '% Passing Math': summary_df.groupby(['School Size'])['% Passing Math'].mean(),
    '% Passing Reading': summary_df.groupby(['School Size'])['% Passing Reading'].mean(),
    '% Overall Passing Rate': summary_df.groupby(['School Size'])['% Overall Passing Rate'].mean()
})

# Format the columns appropriately
size_summary['Average Math Score'] = size_summary['Average Math Score'].map('{:.2f}'.format)
size_summary['Average Reading Score'] = size_summary['Average Reading Score'].map('{:.2f}'.format)
size_summary['% Passing Math'] = size_summary['% Passing Math'].map('{:.2f}%'.format)
size_summary['% Passing Reading'] = size_summary['% Passing Reading'].map('{:.2f}%'.format)
size_summary['% Overall Passing Rate'] = size_summary['% Overall Passing Rate'].map('{:.2f}%'.format)

# Display the size summary DataFrame
size_summary
# Out:
#                    Average Math Score Average Reading Score % Passing Math  \
# School Size
# Small (0-1000)                  83.82                 83.93         93.55%
# Medium (1000-2000)              83.37                 83.86         93.60%
# Large (2000-5000)               77.75                 81.34         69.96%
#
#                    % Passing Reading % Overall Passing Rate
# School Size
# Small (0-1000)                96.10%                 94.82%
# Medium (1000-2000)            96.79%                 95.20%
# Large (2000-5000)             82.77%                 76.36%

# %% [markdown]
# # Scores by School Type

# %%
# Create a DataFrame to summarize scores by school type
type_summary = pd.DataFrame({
    'Average Math Score': summary_df.groupby(['School Type'])['Average Math Score'].mean(),
    'Average Reading Score': summary_df.groupby(['School Type'])['Average Reading Score'].mean(),
    '% Passing Math': summary_df.groupby(['School Type'])['% Passing Math'].mean(),
    '% Passing Reading': summary_df.groupby(['School Type'])['% Passing Reading'].mean(),
    '% Overall Passing Rate': summary_df.groupby(['School Type'])['% Overall Passing Rate'].mean()
})

# Format the columns appropriately
type_summary['Average Math Score'] = type_summary['Average Math Score'].map('{:.2f}'.format)
type_summary['Average Reading Score'] = type_summary['Average Reading Score'].map('{:.2f}'.format)
type_summary['% Passing Math'] = type_summary['% Passing Math'].map('{:.2f}%'.format)
type_summary['% Passing Reading'] = type_summary['% Passing Reading'].map('{:.2f}%'.format)
type_summary['% Overall Passing Rate'] = type_summary['% Overall Passing Rate'].map('{:.2f}%'.format)

# Display the type summary DataFrame
type_summary
# Out:
#             Average Math Score Average Reading Score % Passing Math  \
# School Type
# Charter                  83.47                 83.90         93.62%
# District                 76.96                 80.97         66.55%
#
#             % Passing Reading % Overall Passing Rate
# School Type
# Charter                96.59%                 95.10%
# District               80.80%                 73.67%
